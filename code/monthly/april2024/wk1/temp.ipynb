# %%
from astropy.io import fits 

hdul = fits.open('/Users/yaroslav/Documents/2. work/Research/GitHub/AGN-UMAP/code/monthly/april2024/wk1/QSO_cat_fuji_healpix_only_qso_targets.fits')
hdul[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                  298 / width of table in bytes
# NAXIS2  =                87318 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   59 / number of fields in each row
# TTYPE1  = 'TARGETID'           / label for field   1
# TFORM1  = 'K       '           / data format of field: 8-byte INTEGER
# TTYPE2  = 'Z       '           / label for field   2
# TFORM2  = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE3  = 'ZERR    '           / label for field   3
# TFORM3  = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE4  = 'ZWARN   '           / label for field   4
# TFORM4  = 'K       '           / data format of field: 8-byte INTEGER
# ...
